# %%
D: && cd "DATA SCIENCE AND MACHINE LEARNING SM" && python -m notebook










# Lists 0->1->2
#fruits=["apple","banana","cherry"]
# print(fruits[2])

# List Methods

#fruits=["apple","banana","cherry","apple"]
#fruits.append("orange")
#fruits.insert(1,"orange")
#fruits.extend(["grape","melon"])

#fruits.remove("banana")
#fruits.pop()
#fruits.clear()
#print(fruits.count("apple"))


#numbers=[3,6,8,10,9]
#numbers.sort()
#numbers.reverse()
#print(len(numbers))
#print(numbers)

#country=["Bangladesh","India","Pakistan","USA","UK","Canada","Africa"]
#print(country[0:3])
#print(country[:5])
#print(country[5:])
#print(country[2:6])


#countryList=["Bangladesh","India","Pakistan","USA","UK","Canada","Africa"]
#for item in countryList:
#    print(item)


"""
List Use Case
- Storing User Data
- Inventory Purchase, Sales , Order
- Add to cart, Invoice, dropdown
- User Data Collection
- Table , List,
"""












# Tuples 0->1->2->3
# fruits=("apple","banana","cherry")
# print(fruits[1])

# Tuple Methods

#fruitsTuple=("apple","banana","cherry")
# Tuple convert->  to list
#fruitsList=list(fruitsTuple)

# List convert->  to tuple
#fruitsTuple=tuple(fruitsList)
#print(fruitsTuple)


"""
Tuple Use Case
- Storing User Data
- Inventory Purchase, Sales , Order
- Add to cart, Invoice, dropdown
- User Data Collection
- Table , List,
"""








# SET
# fruits= {"apple", "banana", "cherry","apple"}
# from cgitb import reset

#SET Methods
#fruits= {"apple", "banana", "cherry"}
#fruits.add("Orange")
#fruits.update(["grape","melon"])
#fruits.remove("banana")
#fruits.clear()
#fruits.pop()


# SET UNION
set1={1,2,3}
set2={3,4,5}
result=set1.union(set2)
print(result)



# SET INTERSECTION
#set1={1,2,3}
#set2={3,4,5}
#result=set1.intersection(set2)
#print(result)

# SET Diff
#set1={1,2,3}
#set2={3,4,5}
#result=set1.difference(set2)
#print(result)

"""
Sets Use case
- Removing Duplicate
- Filtering Data
- Mathematical Set Operation
- Unique Elements
"""







# Dictionary

"""
Python - Dictionary
JavaScript - JSON Array/Object
Dart - Map
PHP - Associative Array
"""

# KEY:VALUE Pair Data
# KEY(String):VALUE(Dynamic)
"""
student={
    "name":"Jhon",
    "age":23,
    "subject":"Web Dev",
    "isBangladeshi":True
}
"""
#print(student)
#print(student["name"])


# Dictionary Methods
#
# student={
#     "name":"Jhon",
#     "age":23,
#     "subject":"Web Dev",
#     "isBangladeshi":True
# }

# keys()
# print(student.keys())

# values()
#print(student.values())


#update()
#student.update({"age":30})
#print(student)


#student.pop("name")
#print(student)

# #clear()
# student.clear()
# print(student)











# Dictionary

"""
Python - Dictionary
JavaScript - JSON Array/Object
Dart - Map
PHP - Associative Array
"""

# KEY:VALUE Pair Data
# KEY(String):VALUE(Dynamic)
"""
student={
    "name":"Jhon",
    "age":23,
    "subject":"Web Dev",
    "isBangladeshi":True
}
"""
#print(student)
#print(student["name"])


# Dictionary Methods
#
# student={
#     "name":"Jhon",
#     "age":23,
#     "subject":"Web Dev",
#     "isBangladeshi":True
# }

# keys()
# print(student.keys())

# values()
#print(student.values())


#update()
#student.update({"age":30})
#print(student)


#student.pop("name")
#print(student)

# #clear()
# student.clear()
# print(student)






# print("shofikul islam")
# Out:
# {1, 2, 3, 4, 5}
# '\nstudent={\n    "name":"Jhon",\n    "age":23,\n    "subject":"Web Dev",\n    "isBangladeshi":True\n}\n'

# %%
'''     memory  te koto toko  jaiga   niyeche  ta 
janar  jonno  import sys korte hob e 
 tarpor sys.getsizeof ()   method  likhte 
 hobe  tahole   memory  ar sizen   pawya jabe 
 '''

import sys
x=100
y='shofi'

print(type(x))
print(type(y))

memory=sys.getsizeof(x)
memory2=sys.getsizeof(y)
print(memory)
print(memory2)
# Out:
# <class 'int'>
# <class 'str'>
# 28
# 46

# %%
# import pandas as pd
df = pd.read_excel('studymart.xlsx')
df.head()
df.info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File C:\Program Files\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# D: && cd "DATA SCIENCE AND MACHINE LEARNING SM" && python -m notebook

# ai command   dile jupyter notebook open hobe akbare

# %%
D: && cd "DATA SCIENCE AND MACHINE LEARNING SM" && python -m notebook

# %%
D: && cd "DATA SCIENCE AND MACHINE LEARNING SM" && python -m notebook
